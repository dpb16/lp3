# %%
pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 509.0 kB/s eta 0:01:16
#     --------------------------------------- 0.8/38.8 MB 671.3 kB/s eta 0:00:57
#    - -------------------------------------- 1.0/38.8 MB 751.8 kB/s eta 0:00:51
#    - -------------------------------------- 1.0/38.8 MB 751.8 kB/s eta 0:00:51
#    - -------------------------------------- 1.0/38.8 MB 751.8 kB/s eta 0:00:51
#    - -------------------------------------- 1.3/38.8 MB 699.0 kB/s eta 0:00:54
# ...

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('arrow.png')
plt.imshow(img)
plt.title('MIhir image')
plt.show()

# %%
#image crop

cropped = img[0:100,0:200];
plt.imshow(cropped);
plt.show()

# %%
#resized

resized=cv2.resize(img,(50,50))
plt.imshow(resized);
plt.show()

# %%
#thresold

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
__, thresh=cv2.threshold(gray,0,180,cv2.THRESH_BINARY)
plt.imshow(thresh)
plt.show()

# %%
#contour
contours,_=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
image=img.copy()
contourimage=cv2.drawContours(image,contours,-1,(0,255,0),2)


plt.imshow(contourimage)

plt.show()

# %%
detector=cv2.SimpleBlobDetector_create()
img2=cv2.imread('ferrari.jpg')
keypoints=detector.detect(img2)
blobimage=cv2.drawKeypoints(img2,keypoints,None,(0,250,255),cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
blobrgb = cv2.cvtColor(blobimage, cv2.COLOR_BGR2RGB)

plt.imshow(blobrgb)
plt.show()

# %%
detector=cv2.SimpleBlobDetector_create()
img2=cv2.imread('arrow.png')
keypoints=detector.detect(img2)
blobimage=cv2.drawKeypoints(img2,keypoints,None,(0,250,255),cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
blobrgb = cv2.cvtColor(blobimage, cv2.COLOR_BGR2RGB)

plt.imshow(blobrgb)
plt.show()
